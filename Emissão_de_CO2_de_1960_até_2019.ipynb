# %%
#Libs para Modelagem e Matrizez
import numpy as np
import pandas as pd

#Libs para análises gráficas
import matplotlib.pyplot as plt
import seaborn as sns

#Lib para ignorar avisos
import warnings

#Desabilitando avisos
warnings.filterwarnings('ignore')

#Libs para utilizar o Plotly
import plotly.express as px
import plotly.graph_objects as Dash

# %%
#Lendo a base de dados
base_dados = pd.read_csv('emissao_co2.csv')
base_dados
# Out:
#       country_code country_name  year         value
# 0              ABW        Aruba  1960  11092.675000
# 1              ABW        Aruba  1961  11576.719000
# 2              ABW        Aruba  1962  12713.489000
# 3              ABW        Aruba  1963  12178.107000
# 4              ABW        Aruba  1964  11840.743000
# ...            ...          ...   ...           ...
# 13948          ZWE     Zimbabwe  2015  12430.000305
# 13949          ZWE     Zimbabwe  2016  11020.000458
# 13950          ZWE     Zimbabwe  2017  10340.000153
# 13951          ZWE     Zimbabwe  2018  12380.000114
# 13952          ZWE     Zimbabwe  2019  11760.000229
#
# [13953 rows x 4 columns]

# %%
#Verificando a quantidade de dados presentes
base_dados.shape
# Out:
# (13953, 4)

# %%
#Verificando o tipo de informação
base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13953 entries, 0 to 13952
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  13953 non-null  object
#  1   country_name  13953 non-null  object
#  2   year          13953 non-null  int64
#  3   value         13953 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 436.2+ KB

# %%
#Verificando a existência de valores nulos
base_dados.isnull().sum()
# Out:
# country_code    0
# country_name    0
# year            0
# value           0
# dtype: int64

# %%
#Filtrando o total de emissão de gás de cada ano
emissoes_totais = base_dados.groupby('year').sum().reset_index()

# %%
#Definindo o ano como índice
emissoes_totais.set_index('year', inplace=True)

# %%
#Plotando um gráfico de emissões totais
fig = px.line(emissoes_totais, y='value')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cd0fd17a-146c-438c-881a-8173160b552e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd0fd17a-146c-438c-881a-8173160b552e")) {                    Plotly.newPlot(                        "cd0fd17a-146c-438c-881a-8173160b552e",                        [{"hovertemplate":"year=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[77039802.13822293,76303203.61213699,78590031.30599979,83118160.94214591,87706060.39485565,92699113.20185798,97715241.58633953,100868365.56345204,106392918.27320191,113673801.01187035,124151465.79552913,130364096.50696403,136666583.79393777,144116109.2831636,145397921.65213493,148156291.71798393,156099328.66631466,161611104.06241953,168518453.13786754,173133492.92104486,173836111.47574726,169939883.6677558,171362420.2639598,173770241.82407016,178789125.29656848,187123284.21855775,190155438.620694,195486319.82337642,203073109.88964412,205742189.32938075,177035118.89709657,178491839.4679542,178446919.8639657,179446767.55028453,179775521.3409706,185609131.32409292,189116690.36328992,192013197.95867997,193288353.37475836,193803655.63192916,200252428.73548213,204448916.8069273,208354068.2099918,219757355.291863,231648446.7900773,242146064.33172274,252200205.9163888,262971615.08567232,266620059.23414245,266090322.82762477,283182315.29747826,294855976.73995113,300171206.9771898,306854491.4199534,308289151.44623363,306468970.85434735,307366736.2748323,313124667.8450806,321340582.6435958,323407936.3440489],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"typ ...

# %%
#Plotando um gráfico de emissões de cada país

#Criando uma lista com os nomes dos países
paises = base_dados['country_name'].unique()

#Inicializando a figura
fig = px.line()

#Definindo o título
fig.update_layout(title= 'Emissão de CO2 de cada país de 1960 até 2019', yaxis= dict(title= 'Emissão'), xaxis= dict(title= 'Ano'))

#Loop criando uma trace para cada país
for pais in paises:
  #Filtrando a base de dados para o país que está sendo iterado no momento
  dados_pais = base_dados[base_dados['country_name'] == pais]

  #Adicionando um trace de cada país
  fig.add_scatter(x= dados_pais['year'], y= dados_pais['value'], mode='lines', name=pais)

#Mostrando a figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93ffd77c-4c9f-4121-8021-bc8d5c31d7da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93ffd77c-4c9f-4121-8021-bc8d5c31d7da")) {                    Plotly.newPlot(                        "93ffd77c-4c9f-4121-8021-bc8d5c31d7da",                        [{"hovertemplate":"\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"mode":"lines","name":"Aruba","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"y":[11092.675,11576.719,12713.489,12178.107,11840.743,10623.299,9933.903,12236.779,11378.701,14891.687,16655.514,14495.651,14055.611,15592.084,14132.618,10234.597,21862.654,11419.038,9724.884,10201.594,10498.621,9999.909,11180.683,5746.189,14348.971,16794.86,179.683,447.374,612.389,649.059,487.711,531.715,539.049,649.059,660.06,707.731,726.066,759.069,806.74,810.407,2379.883,2409.219,2438.555,2563.233,2618.238,2720.914,2717.247,2823.59,2658.575,2629.239,2508.228,2500.894,1349.456,861.745,872.746,898.415,883.747],"type":"scatter"},{"mode":"lines","name":"Africa Eastern and Southern","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"y":[118545.90130597,123758.903329795,128093.897814899,132810.332529783,144345.352398305,155803.780096242,157932.257312203,165066.040490079,174004.892685024,182939.984319516,191243.301798035,213550.946400649,217837.985316189,223290.233235483,226298.370018542,231987.508709502,240665.983328627,246129.511760858,250630.43642251,268619.094385202,280929.89416987,308901.806081339,329541.384584102,344021.803023552,365909.758291284,374516.789661811,385101.6709672,388106.04757928,404605.677834358,401747.947890452,304354.882668939,298735.435601561,295090.0,303600.0,312160.0,327430.0,340070.0,356590.0,365690.0,351070.0,355920.0,393150.0,404210.007127375,426379.996828735,457599.99126941,458459.994629025,465440.008163452,486179.996997118,519309.990122914,501940.011456609,529639.997445047,521760.009862482,543439.999304712,565430.012963712,587699.99242574,574029.994986952,578510.015696288,587509.992346167,590040.005281568,603030.016154051],"type":"scatter"},{"mode":"lines","name":"Afghanistan","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"y":[414.371,491.378,689.396,707.731,839.743,1008.425,1092.766,1283.45,1224.778,942.419,1672.152,1895.839,1532.806,1639.149,1917.841,2126.86,1987.514,2390.884,2159.863,2240.537,1760.16,1983.847,2101.191,2522.896,2830.924,3509.319,3142.619,3124.284,2867.594,2775.919,2380.0,2230.0,1390.0,1340.0,1290.0,1240.0,1180.0,1100.0,1040.0,810.0,760.0,730.0,1029.99997138977,1220.00002861023,1029.99997138977,1549.99995231628,1759.99999046326,1769.99998092651,3559.99994277954,4880.00011444092,7110.0001335144,8930.00030517578,8079.99992370605,5989.99977111816,4880.00011444092,5949.99980926514,5300.00019073486,4780.00020980835,6070.00017166138,6079.99992370605],"type":"scatte ...
